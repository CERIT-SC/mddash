# %% [markdown]
# This notebook intentionally avoids headings. Hidden markdown markers define semantic steps instead.

# %% [markdown]
# <!-- pipeline-step: Select input molecule -->

# %%
input_file = 'input.pdb'
print(f'Using {input_file}')

# %% [markdown]
# <!-- pipeline-step: Validate parameters -->

# %%
nanoseconds = 0.05
assert nanoseconds > 0
print('Parameters are valid')

# %% [markdown]
# <!-- pipeline-step: Produce report -->

# %%
print('Report ready')
