# %% [markdown]
# # Heading discovery demo
#
# This notebook uses ordinary markdown headings. The tracker groups code cells under the nearest heading.

# %% [markdown]
# ## Configuration

# %%
sample_name = "demo-protein"
temperature = 300
print(f"Configured {sample_name} at {temperature} K")

# %% [markdown]
# ## Preparation

# %%
import time

time.sleep(0.3)
prepared = True
print("Input files prepared")

# %% [markdown]
# ## Analysis

# %%
time.sleep(0.3)
print("Analysis complete")
