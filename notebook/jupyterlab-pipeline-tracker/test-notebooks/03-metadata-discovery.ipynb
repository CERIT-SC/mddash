# %% [markdown]
# Metadata discovery demo. The notebook metadata defines the pipeline, so headings are not required.

# %%
configuration = {"force_field": "amber99sb", "water": "tip3p"}
print(configuration)

# %%
box_size = 8.5
print(f"Box size: {box_size} nm")

# %%
energy = -1234.5
print(f"Initial energy: {energy}")

# %%
print("Exported clean structure and summary table")
