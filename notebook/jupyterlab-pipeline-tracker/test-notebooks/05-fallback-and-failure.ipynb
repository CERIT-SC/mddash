# %% [markdown]
# Fallback and failure demo. There are no headings, markers, or metadata, so each non-empty code cell becomes a fallback step.

# %%
value = 42
print('First fallback step succeeded')

# %%
raise RuntimeError('Intentional failure for tracker validation')

# %%
print('This cell should not run after the intentional failure')
