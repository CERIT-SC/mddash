# %% [markdown]
# This notebook demonstrates explicit author annotations on code cells.

# %%
print('This step label comes from cell metadata')

# %%
# pipeline-step: Inline code marker
print('This step label comes from a code comment marker')

# %%
# tracker.step('Tracker call marker')
print('This step label comes from tracker.step(...)')
